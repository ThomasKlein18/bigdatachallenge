# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

classes = ['run', 'walk', 'stand', 'sit', 'sit-to-stand', 'stand-to-sit', 
        'stair-up', 'stair-down', 'jump-one-leg', 'jump-two-leg', 'curve-left-step', 
        'curve-right-step', 'curve-left-spin-Lfirst', 'curve-left-spin-Rfirst', 
        'curve-right-spin-Lfirst', 'curve-right-spin-Rfirst', 'lateral-shuffle-left', 
        'lateral-shuffle-right','v-cut-left-Lfirst', 'v-cut-left-Rfirst', 'v-cut-right-Lfirst', 'v-cut-right-Rfirst']

# %%
def compare_results(file1, file2):
    df1 = pd.read_csv(file1).values[:,2]
    df2 = pd.read_csv(file2).values[:,2]
    
    d1 = dict.fromkeys(classes, 0)
    d2 = dict.fromkeys(classes, 0)
    
    count = 0
    for idx, (i,j) in enumerate(zip(df1,df2)):
        
        d1[i] += 1
        d2[j] += 1
        
        if i != j:
            print("Difference in line {}: {} vs. {}".format(idx, i,j))
            count += 1
    
    print("{} differences found in total.".format(count))
    
    def plot_hist(d1):
        objects = np.arange(0,22)
        y_pos = np.arange(len(objects))
        performance = d1.values()

        plt.bar(y_pos, performance, align='center', alpha=0.5)
        plt.xticks(y_pos, objects)
        plt.ylabel('occurences')
        plt.title('distribution over labels for d1')

        plt.show()
        
    plot_hist(d1)
    plot_hist(d2)

# %%
compare_results("abgabe1.csv","challengephil2.csv")
# Out:
# Difference in line 0: walk vs. curve-left-step
# Difference in line 1: v-cut-right-Lfirst vs. v-cut-left-Rfirst
# Difference in line 2: curve-left-spin-Lfirst vs. curve-right-spin-Lfirst
# Difference in line 6: stair-down vs. curve-right-step
# Difference in line 9: curve-right-step vs. curve-left-step
# Difference in line 10: curve-right-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 11: v-cut-left-Lfirst vs. v-cut-right-Lfirst
# Difference in line 13: run vs. lateral-shuffle-right
# Difference in line 15: v-cut-right-Lfirst vs. v-cut-left-Rfirst
# Difference in line 18: v-cut-left-Rfirst vs. v-cut-right-Lfirst
# Difference in line 20: curve-right-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 25: stand vs. sit
# Difference in line 27: curve-left-step vs. jump-two-leg
# Difference in line 29: curve-right-step vs. stair-down
# Difference in line 30: v-cut-left-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 32: v-cut-right-Rfirst vs. v-cut-left-Rfirst
# Difference in line 35: v-cut-left-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 37: v-cut-right-Lfirst vs. stair-down
# Difference in line 38: curve-right-step vs. jump-one-leg
# Difference in line 39: jump-two-leg vs. walk
# Difference in line 40: walk vs. jump-two-leg
# Difference in line 46: v-cut-right-Lfirst vs. stair-down
# Difference in line 50: lateral-shuffle-right vs. lateral-shuffle-left
# Difference in line 54: v-cut-left-Lfirst vs. v-cut-right-Rfirst
# Difference in line 55: curve-right-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 56: run vs. stair-up
# Difference in line 59: curve-right-step vs. curve-left-step
# Difference in line 60: v-cut-left-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 61: v-cut-left-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 64: curve-left-spin-Rfirst vs. curve-left-spin-Lfirst
# Difference in line 66: sit-to-stand vs. stand-to-sit
# Difference in line 67: curve-left-spin-Rfirst vs. curve-left-spin-Lfirst
# Difference in line 69: lateral-shuffle-right vs. lateral-shuffle-left
# Difference in line 70: walk vs. curve-left-step
# Difference in line 71: curve-left-spin-Rfirst vs. curve-left-spin-Lfirst
# Difference in line 73: walk vs. jump-two-leg
# Difference in line 74: walk vs. jump-two-leg
# Difference in line 76: lateral-shuffle-left vs. run
# Difference in line 77: curve-left-step vs. jump-two-leg
# Difference in line 78: stair-down vs. curve-left-step
# Difference in line 79: v-cut-right-Rfirst vs. v-cut-right-Lfirst
# Difference in line 80: run vs. stair-up
# Difference in line 81: walk vs. v-cut-left-Rfirst
# Difference in line 84: v-cut-right-Rfirst vs. v-cut-right-Lfirst
# Difference in line 88: run vs. stair-up
# Difference in line 91: curve-left-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 92: v-cut-left-Lfirst vs. v-cut-left-Rfirst
# Difference in line 97: v-cut-right-Rfirst vs. stair-down
# Difference in line 98: walk vs. jump-two-leg
# Difference in line 100: curve-right-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 101: curve-right-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 105: curve-left-spin-Rfirst vs. curve-left-spin-Lfirst
# Difference in line 110: lateral-shuffle-right vs. lateral-shuffle-left
# Difference in line 112: curve-left-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 115: curve-right-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 118: walk vs. jump-two-leg
# Difference in line 119: v-cut-right-Lfirst vs. v-cut-left-Rfirst
# Difference in line 120: curve-left-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 121: lateral-shuffle-right vs. lateral-shuffle-left
# Difference in line 123: jump-two-leg vs. walk
# Difference in line 124: jump-two-leg vs. stair-up
# Difference in line 125: curve-right-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 126: curve-left-spin-Lfirst vs. v-cut-left-Lfirst
# Difference in line 127: v-cut-right-Lfirst vs. v-cut-left-Rfirst
# Difference in line 132: v-cut-left-Rfirst vs. v-cut-right-Rfirst
# Difference in line 133: curve-left-spin-Rfirst vs. curve-left-spin-Lfirst
# Difference in line 135: sit-to-stand vs. stand-to-sit
# Difference in line 137: v-cut-left-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 138: v-cut-right-Rfirst vs. v-cut-left-Rfirst
# Difference in line 139: lateral-shuffle-left vs. stair-down
# Difference in line 140: curve-right-step vs. curve-left-step
# Difference in line 142: curve-left-spin-Rfirst vs. v-cut-right-Lfirst
# Difference in line 143: sit-to-stand vs. stand-to-sit
# Difference in line 145: v-cut-right-Lfirst vs. jump-one-leg
# Difference in line 147: curve-left-spin-Rfirst vs. curve-left-spin-Lfirst
# Difference in line 148: curve-right-step vs. curve-left-step
# Difference in line 151: curve-left-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 152: curve-left-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 155: curve-right-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 156: v-cut-right-Lfirst vs. v-cut-left-Rfirst
# Difference in line 157: run vs. v-cut-left-Rfirst
# Difference in line 161: v-cut-right-Rfirst vs. v-cut-left-Rfirst
# Difference in line 163: curve-left-step vs. jump-two-leg
# Difference in line 168: curve-right-step vs. walk
# Difference in line 173: walk vs. stair-up
# Difference in line 174: jump-two-leg vs. walk
# Difference in line 175: v-cut-right-Rfirst vs. stair-down
# Difference in line 176: v-cut-right-Rfirst vs. v-cut-left-Rfirst
# Difference in line 177: lateral-shuffle-right vs. lateral-shuffle-left
# Difference in line 178: curve-right-step vs. curve-right-spin-Lfirst
# Difference in line 179: v-cut-right-Rfirst vs. v-cut-right-Lfirst
# Difference in line 180: curve-right-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 181: curve-left-step vs. jump-two-leg
# Difference in line 182: v-cut-right-Lfirst vs. v-cut-left-Rfirst
# Difference in line 183: curve-left-spin-Rfirst vs. curve-left-spin-Lfirst
# Difference in line 185: curve-left-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 186: curve-right-spin-Lfirst vs. v-cut-left-Rfirst
# Difference in line 190: v-cut-left-Rfirst vs. v-cut-right-Rfirst
# Difference in line 193: curve-right-spin-Lfirst vs. v-cut-left-Rfirst
# Difference in line 194: curve-right-step vs. stair-down
# Difference in line 195: v-cut-left-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 196: lateral-shuffle-right vs. lateral-shuffle-left
# Difference in line 197: v-cut-left-Lfirst vs. v-cut-left-Rfirst
# Difference in line 198: v-cut-right-Rfirst vs. v-cut-left-Rfirst
# Difference in line 201: v-cut-left-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 204: v-cut-right-Rfirst vs. v-cut-left-Rfirst
# Difference in line 205: curve-left-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 206: jump-two-leg vs. v-cut-left-Lfirst
# Difference in line 208: v-cut-left-Rfirst vs. v-cut-right-Lfirst
# Difference in line 209: curve-left-spin-Lfirst vs. curve-right-spin-Lfirst
# Difference in line 210: curve-right-step vs. stair-down
# Difference in line 215: v-cut-right-Lfirst vs. v-cut-right-Rfirst
# Difference in line 216: curve-right-step vs. curve-left-step
# Difference in line 217: v-cut-left-Rfirst vs. stair-down
# Difference in line 218: curve-left-step vs. jump-two-leg
# Difference in line 219: v-cut-left-Lfirst vs. v-cut-right-Lfirst
# Difference in line 221: v-cut-right-Rfirst vs. v-cut-right-Lfirst
# Difference in line 222: run vs. lateral-shuffle-left
# Difference in line 223: curve-right-step vs. curve-left-step
# Difference in line 225: v-cut-right-Lfirst vs. v-cut-left-Rfirst
# Difference in line 228: curve-left-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 229: curve-right-step vs. jump-one-leg
# Difference in line 230: run vs. stair-up
# Difference in line 231: jump-two-leg vs. jump-one-leg
# Difference in line 232: run vs. lateral-shuffle-left
# Difference in line 233: walk vs. jump-two-leg
# Difference in line 236: v-cut-left-Lfirst vs. v-cut-left-Rfirst
# Difference in line 239: curve-left-step vs. jump-two-leg
# Difference in line 240: curve-right-step vs. stair-down
# Difference in line 242: v-cut-left-Rfirst vs. stair-down
# Difference in line 245: curve-left-spin-Rfirst vs. curve-left-spin-Lfirst
# Difference in line 252: lateral-shuffle-right vs. lateral-shuffle-left
# Difference in line 254: v-cut-left-Rfirst vs. stair-down
# Difference in line 256: v-cut-right-Rfirst vs. v-cut-left-Rfirst
# Difference in line 258: v-cut-left-Lfirst vs. stair-up
# Difference in line 263: lateral-shuffle-right vs. lateral-shuffle-left
# Difference in line 266: curve-left-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 267: curve-right-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 268: curve-left-spin-Rfirst vs. curve-left-spin-Lfirst
# Difference in line 272: curve-right-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 273: curve-right-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 278: lateral-shuffle-right vs. lateral-shuffle-left
# Difference in line 280: stand vs. sit
# Difference in line 282: curve-right-step vs. curve-left-step
# Difference in line 283: sit-to-stand vs. stand-to-sit
# Difference in line 286: v-cut-left-Rfirst vs. stair-down
# Difference in line 287: curve-left-spin-Rfirst vs. curve-left-spin-Lfirst
# Difference in line 291: v-cut-left-Lfirst vs. v-cut-left-Rfirst
# Difference in line 297: curve-left-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 298: curve-left-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 299: curve-right-step vs. curve-left-step
# Difference in line 300: run vs. lateral-shuffle-left
# Difference in line 304: curve-right-step vs. curve-left-step
# Difference in line 306: stair-down vs. curve-left-step
# Difference in line 311: curve-left-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 312: curve-left-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 314: walk vs. jump-two-leg
# Difference in line 316: v-cut-left-Rfirst vs. v-cut-right-Rfirst
# Difference in line 320: lateral-shuffle-right vs. lateral-shuffle-left
# Difference in line 323: curve-left-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 324: v-cut-right-Lfirst vs. v-cut-right-Rfirst
# Difference in line 325: curve-right-step vs. curve-left-step
# Difference in line 327: v-cut-left-Lfirst vs. stair-up
# Difference in line 328: curve-right-step vs. run
# Difference in line 329: curve-left-spin-Rfirst vs. curve-left-spin-Lfirst
# Difference in line 330: v-cut-left-Rfirst vs. v-cut-right-Lfirst
# Difference in line 331: v-cut-left-Rfirst vs. stair-down
# Difference in line 332: stand vs. sit
# Difference in line 337: v-cut-left-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 343: lateral-shuffle-right vs. lateral-shuffle-left
# Difference in line 344: curve-right-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 345: lateral-shuffle-right vs. lateral-shuffle-left
# Difference in line 346: sit-to-stand vs. stand-to-sit
# Difference in line 347: curve-right-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 349: stair-down vs. run
# Difference in line 351: stand vs. sit
# Difference in line 353: v-cut-left-Lfirst vs. v-cut-left-Rfirst
# Difference in line 355: curve-left-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 357: curve-right-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 358: curve-left-spin-Rfirst vs. v-cut-left-Lfirst
# Difference in line 359: v-cut-left-Rfirst vs. v-cut-right-Rfirst
# Difference in line 361: curve-right-step vs. stair-down
# Difference in line 363: curve-left-step vs. jump-two-leg
# Difference in line 364: curve-left-spin-Rfirst vs. curve-left-spin-Lfirst
# Difference in line 366: curve-right-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 367: stand vs. sit
# Difference in line 371: v-cut-left-Lfirst vs. v-cut-left-Rfirst
# Difference in line 372: v-cut-left-Rfirst vs. stair-down
# Difference in line 373: curve-right-step vs. curve-left-step
# Difference in line 374: curve-left-spin-Rfirst vs. curve-right-step
# Difference in line 377: curve-right-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 381: sit-to-stand vs. stand-to-sit
# Difference in line 383: sit-to-stand vs. stand-to-sit
# Difference in line 388: v-cut-left-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 389: curve-left-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 391: curve-left-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 392: v-cut-right-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 393: curve-right-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 394: curve-left-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 397: jump-one-leg vs. jump-two-leg
# Difference in line 398: curve-right-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 400: jump-one-leg vs. curve-left-step
# Difference in line 404: jump-two-leg vs. v-cut-left-Rfirst
# Difference in line 405: curve-right-step vs. curve-left-step
# Difference in line 409: lateral-shuffle-right vs. lateral-shuffle-left
# Difference in line 410: curve-left-spin-Rfirst vs. curve-left-spin-Lfirst
# Difference in line 413: v-cut-left-Lfirst vs. stair-down
# Difference in line 414: curve-left-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 415: sit-to-stand vs. stand-to-sit
# Difference in line 416: run vs. stair-up
# Difference in line 417: v-cut-left-Rfirst vs. v-cut-right-Lfirst
# Difference in line 420: run vs. stair-up
# Difference in line 424: walk vs. jump-two-leg
# Difference in line 430: walk vs. jump-two-leg
# Difference in line 433: curve-left-spin-Rfirst vs. jump-one-leg
# Difference in line 434: curve-right-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 438: curve-left-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 439: walk vs. jump-two-leg
# Difference in line 441: lateral-shuffle-left vs. lateral-shuffle-right
# Difference in line 442: curve-left-step vs. stair-up
# Difference in line 446: curve-left-step vs. walk
# Difference in line 451: run vs. walk
# Difference in line 457: v-cut-left-Rfirst vs. v-cut-right-Rfirst
# Difference in line 458: jump-one-leg vs. jump-two-leg
# Difference in line 460: v-cut-left-Lfirst vs. curve-left-spin-Lfirst
# Difference in line 462: jump-one-leg vs. curve-right-spin-Lfirst
# Difference in line 465: v-cut-right-Lfirst vs. curve-right-spin-Rfirst
# Difference in line 467: curve-left-step vs. curve-right-step
# Difference in line 468: v-cut-left-Rfirst vs. v-cut-right-Rfirst
# Difference in line 471: v-cut-left-Rfirst vs. curve-left-spin-Lfirst
# Difference in line 474: v-cut-left-Lfirst vs. curve-left-spin-Lfirst
# Difference in line 477: run vs. lateral-shuffle-left
# Difference in line 478: curve-left-spin-Lfirst vs. curve-right-spin-Lfirst
# Difference in line 481: curve-left-step vs. curve-right-step
# Difference in line 482: walk vs. curve-right-step
# Difference in line 483: lateral-shuffle-left vs. lateral-shuffle-right
# Difference in line 484: run vs. lateral-shuffle-left
# Difference in line 486: v-cut-left-Rfirst vs. v-cut-right-Rfirst
# Difference in line 487: v-cut-right-Lfirst vs. curve-left-spin-Rfirst
# Difference in line 488: run vs. lateral-shuffle-left
# Difference in line 490: curve-left-step vs. curve-right-step
# Difference in line 494: curve-right-step vs. walk
# Difference in line 501: v-cut-left-Lfirst vs. curve-left-spin-Lfirst
# Difference in line 502: v-cut-left-Rfirst vs. v-cut-right-Rfirst
# Difference in line 507: stand vs. sit
# Difference in line 508: run vs. lateral-shuffle-left
# Difference in line 509: jump-one-leg vs. v-cut-right-Rfirst
# Difference in line 514: curve-left-step vs. walk
# Difference in line 515: run vs. lateral-shuffle-left
# Difference in line 518: curve-right-step vs. curve-left-spin-Rfirst
# Difference in line 520: v-cut-left-Lfirst vs. curve-left-spin-Lfirst
# Difference in line 522: stand vs. sit
# Difference in line 524: curve-left-step vs. curve-right-spin-Lfirst
# Difference in line 526: stand vs. sit
# Difference in line 531: walk vs. run
# Difference in line 532: jump-one-leg vs. jump-two-leg
# Difference in line 536: curve-left-step vs. curve-right-step
# Difference in line 539: stand vs. sit
# Difference in line 540: v-cut-left-Rfirst vs. v-cut-right-Rfirst
# Difference in line 548: walk vs. curve-right-step
# Difference in line 550: curve-left-step vs. curve-right-step
# Difference in line 551: walk vs. curve-right-step
# Difference in line 552: curve-right-step vs. curve-right-spin-Rfirst
# Difference in line 553: walk vs. run
# Difference in line 554: curve-left-step vs. curve-right-step
# Difference in line 555: jump-one-leg vs. jump-two-leg
# Difference in line 564: curve-left-spin-Rfirst vs. v-cut-right-Rfirst
# Difference in line 565: v-cut-left-Rfirst vs. curve-left-spin-Rfirst
# Difference in line 566: stand vs. sit
# Difference in line 568: jump-two-leg vs. sit-to-stand
# Difference in line 571: stand vs. sit
# Difference in line 573: curve-left-spin-Lfirst vs. curve-right-spin-Rfirst
# Difference in line 574: curve-left-step vs. curve-right-step
# Difference in line 575: v-cut-right-Lfirst vs. jump-two-leg
# Difference in line 576: curve-left-step vs. curve-right-step
# Difference in line 577: v-cut-right-Rfirst vs. curve-right-spin-Rfirst
# Difference in line 578: jump-one-leg vs. curve-right-spin-Lfirst
# Difference in line 579: jump-one-leg vs. jump-two-leg
# Difference in line 582: curve-left-spin-Lfirst vs. curve-right-spin-Lfirst
# Difference in line 588: v-cut-right-Lfirst vs. curve-right-spin-Rfirst
# Difference in line 593: jump-one-leg vs. v-cut-right-Rfirst
# Difference in line 597: stand vs. sit
# Difference in line 601: curve-right-step vs. curve-right-spin-Lfirst
# Difference in line 606: curve-left-spin-Lfirst vs. curve-right-spin-Lfirst
# Difference in line 608: stand vs. sit
# Difference in line 609: curve-left-spin-Rfirst vs. curve-left-spin-Lfirst
# Difference in line 611: walk vs. curve-right-step
# Difference in line 612: jump-one-leg vs. curve-right-spin-Lfirst
# Difference in line 613: jump-one-leg vs. jump-two-leg
# Difference in line 614: lateral-shuffle-right vs. lateral-shuffle-left
# Difference in line 615: v-cut-left-Rfirst vs. v-cut-right-Rfirst
# Difference in line 619: lateral-shuffle-left vs. lateral-shuffle-right
# Difference in line 623: curve-right-step vs. curve-left-step
# Difference in line 624: v-cut-left-Rfirst vs. v-cut-right-Rfirst
# Difference in line 628: v-cut-left-Lfirst vs. curve-left-spin-Lfirst
# Difference in line 633: curve-left-spin-Rfirst vs. v-cut-right-Rfirst
# Difference in line 636: curve-left-step vs. curve-right-step
# Difference in line 641: stand vs. sit
# Difference in line 644: curve-left-spin-Lfirst vs. curve-right-spin-Lfirst
# Difference in line 645: curve-right-step vs. jump-one-leg
# Difference in line 646: walk vs. run
# Difference in line 647: v-cut-left-Rfirst vs. curve-left-spin-Rfirst
# Difference in line 650: jump-one-leg vs. curve-right-spin-Lfirst
# Difference in line 652: lateral-shuffle-left vs. run
# Difference in line 653: curve-left-step vs. run
# Difference in line 654: v-cut-right-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 655: stand vs. sit
# Difference in line 657: curve-left-spin-Rfirst vs. v-cut-left-Lfirst
# Difference in line 662: walk vs. curve-right-step
# Difference in line 663: v-cut-left-Rfirst vs. curve-left-spin-Rfirst
# Difference in line 668: jump-one-leg vs. curve-right-spin-Lfirst
# Difference in line 671: jump-one-leg vs. jump-two-leg
# Difference in line 679: run vs. lateral-shuffle-left
# Difference in line 680: stand vs. sit
# Difference in line 684: curve-left-step vs. curve-right-spin-Lfirst
# Difference in line 687: curve-left-spin-Rfirst vs. v-cut-right-Rfirst
# Difference in line 690: jump-one-leg vs. v-cut-right-Rfirst
# Difference in line 693: lateral-shuffle-left vs. lateral-shuffle-right
# Difference in line 694: stair-down vs. curve-right-step
# Difference in line 697: curve-left-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 698: curve-left-step vs. curve-right-step
# Difference in line 700: stand vs. sit
# Difference in line 705: v-cut-left-Rfirst vs. curve-left-spin-Rfirst
# Difference in line 706: curve-left-spin-Lfirst vs. curve-right-spin-Rfirst
# Difference in line 710: curve-left-step vs. walk
# Difference in line 712: curve-left-spin-Rfirst vs. v-cut-right-Rfirst
# Difference in line 718: run vs. lateral-shuffle-left
# Difference in line 719: v-cut-left-Rfirst vs. v-cut-right-Rfirst
# Difference in line 720: curve-left-spin-Lfirst vs. curve-left-spin-Rfirst
# Difference in line 721: curve-left-spin-Lfirst vs. curve-right-spin-Lfirst
# Difference in line 722: stair-down vs. v-cut-left-Rfirst
# Difference in line 729: curve-right-step vs. walk
# Difference in line 732: run vs. lateral-shuffle-left
# Difference in line 733: curve-right-step vs. walk
# Difference in line 734: walk vs. curve-right-step
# Difference in line 735: curve-left-step vs. curve-left-spin-Rfirst
# Difference in line 736: stand vs. sit
# Difference in line 738: v-cut-left-Rfirst vs. v-cut-right-Rfirst
# Difference in line 739: stair-up vs. lateral-shuffle-right
# Difference in line 740: v-cut-left-Lfirst vs. curve-left-spin-Lfirst
# Difference in line 741: v-cut-left-Lfirst vs. curve-left-spin-Lfirst
# Difference in line 742: jump-one-leg vs. curve-right-spin-Lfirst
# Difference in line 746: v-cut-right-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 749: curve-left-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 751: stair-up vs. lateral-shuffle-right
# Difference in line 752: curve-left-step vs. curve-right-step
# Difference in line 754: v-cut-left-Lfirst vs. curve-left-spin-Lfirst
# Difference in line 755: stair-up vs. lateral-shuffle-right
# Difference in line 756: curve-left-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 758: jump-one-leg vs. v-cut-right-Rfirst
# Difference in line 759: curve-left-spin-Lfirst vs. curve-right-spin-Lfirst
# Difference in line 762: stair-up vs. stair-down
# Difference in line 765: jump-one-leg vs. curve-right-spin-Lfirst
# Difference in line 766: curve-left-step vs. curve-right-step
# Difference in line 771: v-cut-left-Lfirst vs. curve-left-spin-Lfirst
# Difference in line 773: jump-one-leg vs. jump-two-leg
# Difference in line 776: stair-up vs. stair-down
# Difference in line 777: v-cut-left-Rfirst vs. lateral-shuffle-left
# Difference in line 781: walk vs. run
# Difference in line 782: curve-left-step vs. walk
# Difference in line 783: stand vs. sit
# Difference in line 788: stand vs. sit
# Difference in line 789: v-cut-left-Rfirst vs. v-cut-right-Rfirst
# Difference in line 790: jump-one-leg vs. v-cut-right-Rfirst
# Difference in line 791: curve-left-spin-Rfirst vs. curve-left-spin-Lfirst
# Difference in line 792: curve-left-spin-Rfirst vs. curve-left-spin-Lfirst
# Difference in line 795: lateral-shuffle-left vs. curve-right-spin-Lfirst
# Difference in line 796: v-cut-left-Rfirst vs. v-cut-right-Rfirst
# Difference in line 797: lateral-shuffle-left vs. curve-right-spin-Lfirst
# Difference in line 798: v-cut-right-Lfirst vs. curve-right-spin-Lfirst
# Difference in line 803: jump-one-leg vs. curve-right-spin-Lfirst
# Difference in line 804: stand vs. sit
# Difference in line 807: curve-left-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 808: lateral-shuffle-left vs. lateral-shuffle-right
# Difference in line 809: v-cut-right-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 812: curve-left-spin-Lfirst vs. curve-right-spin-Lfirst
# Difference in line 813: stand vs. sit
# Difference in line 827: stand vs. sit
# Difference in line 828: curve-right-step vs. walk
# Difference in line 835: curve-left-step vs. curve-right-step
# Difference in line 836: jump-one-leg vs. curve-right-spin-Lfirst
# Difference in line 837: v-cut-left-Lfirst vs. curve-left-spin-Lfirst
# Difference in line 839: jump-one-leg vs. jump-two-leg
# Difference in line 843: v-cut-right-Lfirst vs. curve-left-spin-Lfirst
# Difference in line 850: stand vs. sit
# Difference in line 857: curve-left-step vs. curve-right-step
# Difference in line 859: lateral-shuffle-left vs. lateral-shuffle-right
# Difference in line 865: v-cut-left-Rfirst vs. curve-left-spin-Rfirst
# Difference in line 866: walk vs. curve-right-step
# Difference in line 876: curve-left-step vs. curve-right-step
# Difference in line 877: v-cut-right-Rfirst vs. jump-two-leg
# Difference in line 882: walk vs. curve-left-step
# Difference in line 889: lateral-shuffle-left vs. lateral-shuffle-right
# Difference in line 893: stand vs. sit
# Difference in line 894: v-cut-left-Rfirst vs. jump-two-leg
# Difference in line 895: curve-left-spin-Lfirst vs. curve-right-spin-Lfirst
# Difference in line 899: stand vs. sit
# Difference in line 900: curve-right-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 904: v-cut-left-Rfirst vs. jump-one-leg
# Difference in line 905: v-cut-left-Lfirst vs. jump-one-leg
# Difference in line 906: v-cut-right-Lfirst vs. v-cut-right-Rfirst
# Difference in line 910: v-cut-left-Lfirst vs. v-cut-right-Lfirst
# Difference in line 911: v-cut-left-Rfirst vs. jump-two-leg
# Difference in line 915: stair-down vs. lateral-shuffle-right
# Difference in line 916: stair-down vs. lateral-shuffle-right
# Difference in line 917: stair-down vs. lateral-shuffle-right
# Difference in line 919: stair-down vs. lateral-shuffle-left
# Difference in line 924: v-cut-left-Lfirst vs. v-cut-right-Lfirst
# Difference in line 926: curve-right-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 927: v-cut-right-Rfirst vs. curve-left-spin-Rfirst
# Difference in line 928: v-cut-right-Rfirst vs. v-cut-right-Lfirst
# Difference in line 930: v-cut-left-Rfirst vs. jump-two-leg
# Difference in line 933: walk vs. curve-right-step
# Difference in line 934: lateral-shuffle-left vs. lateral-shuffle-right
# Difference in line 936: stair-down vs. lateral-shuffle-left
# Difference in line 937: curve-left-step vs. curve-right-step
# Difference in line 938: walk vs. curve-right-step
# Difference in line 945: curve-left-spin-Lfirst vs. curve-right-spin-Lfirst
# Difference in line 948: walk vs. curve-right-step
# Difference in line 950: v-cut-left-Rfirst vs. jump-one-leg
# Difference in line 951: stair-down vs. lateral-shuffle-left
# Difference in line 952: walk vs. curve-right-step
# Difference in line 956: v-cut-right-Rfirst vs. curve-left-spin-Rfirst
# Difference in line 962: v-cut-left-Lfirst vs. v-cut-right-Lfirst
# Difference in line 963: stair-down vs. lateral-shuffle-right
# Difference in line 968: curve-left-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 970: stand vs. sit
# Difference in line 971: run vs. stair-down
# Difference in line 972: stair-down vs. lateral-shuffle-right
# Difference in line 973: v-cut-left-Rfirst vs. jump-two-leg
# Difference in line 976: walk vs. curve-left-step
# Difference in line 978: v-cut-right-Rfirst vs. v-cut-right-Lfirst
# Difference in line 980: curve-left-step vs. curve-right-step
# Difference in line 981: v-cut-right-Rfirst vs. v-cut-right-Lfirst
# Difference in line 988: walk vs. curve-left-step
# Difference in line 989: stair-down vs. lateral-shuffle-right
# Difference in line 992: v-cut-left-Lfirst vs. jump-two-leg
# Difference in line 995: stair-down vs. lateral-shuffle-left
# Difference in line 996: curve-left-spin-Lfirst vs. curve-right-spin-Lfirst
# Difference in line 999: v-cut-left-Rfirst vs. jump-one-leg
# Difference in line 1000: stand vs. sit
# Difference in line 1005: curve-left-step vs. curve-right-step
# Difference in line 1011: stand vs. sit
# Difference in line 1017: v-cut-left-Rfirst vs. jump-two-leg
# Difference in line 1030: v-cut-left-Rfirst vs. jump-two-leg
# Difference in line 1033: stand-to-sit vs. sit-to-stand
# Difference in line 1034: stand vs. sit
# Difference in line 1039: stair-down vs. lateral-shuffle-left
# Difference in line 1040: v-cut-right-Rfirst vs. v-cut-right-Lfirst
# Difference in line 1042: curve-left-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 1045: stand vs. sit
# Difference in line 1046: walk vs. curve-right-step
# Difference in line 1049: walk vs. curve-right-step
# Difference in line 1056: stand vs. sit
# Difference in line 1059: walk vs. curve-right-step
# Difference in line 1066: v-cut-right-Rfirst vs. jump-two-leg
# Difference in line 1067: v-cut-left-Rfirst vs. jump-one-leg
# Difference in line 1068: v-cut-left-Rfirst vs. jump-one-leg
# Difference in line 1069: v-cut-right-Rfirst vs. lateral-shuffle-right
# Difference in line 1074: stair-down vs. lateral-shuffle-right
# Difference in line 1075: v-cut-left-Rfirst vs. jump-one-leg
# Difference in line 1076: lateral-shuffle-right vs. lateral-shuffle-left
# Difference in line 1077: jump-two-leg vs. jump-one-leg
# Difference in line 1080: stand vs. sit
# Difference in line 1082: v-cut-left-Lfirst vs. jump-one-leg
# Difference in line 1087: curve-left-step vs. walk
# Difference in line 1096: curve-left-spin-Rfirst vs. jump-one-leg
# Difference in line 1097: curve-left-spin-Rfirst vs. curve-left-spin-Lfirst
# Difference in line 1101: v-cut-left-Rfirst vs. jump-one-leg
# Difference in line 1104: walk vs. curve-left-step
# Difference in line 1108: stair-down vs. lateral-shuffle-right
# Difference in line 1109: v-cut-left-Rfirst vs. curve-left-spin-Rfirst
# Difference in line 1110: walk vs. curve-right-step
# Difference in line 1121: stand vs. sit
# Difference in line 1122: walk vs. stair-up
# Difference in line 1129: v-cut-left-Rfirst vs. curve-left-spin-Rfirst
# Difference in line 1130: curve-left-spin-Lfirst vs. curve-left-spin-Rfirst
# Difference in line 1132: v-cut-left-Rfirst vs. jump-two-leg
# Difference in line 1143: stand vs. sit
# Difference in line 1144: v-cut-left-Lfirst vs. sit-to-stand
# Difference in line 1145: walk vs. curve-left-step
# Difference in line 1146: stair-down vs. lateral-shuffle-left
# Difference in line 1148: stand vs. sit
# Difference in line 1149: stair-down vs. lateral-shuffle-left
# Difference in line 1151: v-cut-left-Lfirst vs. jump-one-leg
# Difference in line 1153: v-cut-right-Rfirst vs. v-cut-right-Lfirst
# Difference in line 1154: stair-down vs. lateral-shuffle-right
# Difference in line 1155: lateral-shuffle-right vs. lateral-shuffle-left
# Difference in line 1156: curve-left-step vs. curve-right-step
# Difference in line 1162: stair-down vs. lateral-shuffle-left
# Difference in line 1163: stand vs. sit
# Difference in line 1167: v-cut-right-Rfirst vs. v-cut-right-Lfirst
# Difference in line 1177: v-cut-left-Lfirst vs. v-cut-right-Lfirst
# Difference in line 1178: jump-two-leg vs. jump-one-leg
# Difference in line 1181: stair-down vs. lateral-shuffle-left
# Difference in line 1184: walk vs. curve-right-step
# Difference in line 1186: v-cut-left-Lfirst vs. jump-one-leg
# Difference in line 1192: stair-down vs. lateral-shuffle-right
# Difference in line 1196: walk vs. curve-right-step
# Difference in line 1198: curve-left-step vs. curve-right-step
# Difference in line 1205: walk vs. curve-right-step
# Difference in line 1208: v-cut-right-Rfirst vs. jump-two-leg
# Difference in line 1212: walk vs. curve-left-step
# Difference in line 1214: stand vs. sit
# Difference in line 1217: stair-down vs. lateral-shuffle-right
# Difference in line 1218: curve-left-step vs. curve-right-step
# Difference in line 1224: v-cut-right-Rfirst vs. v-cut-left-Rfirst
# Difference in line 1230: stand vs. sit
# Difference in line 1231: stair-up vs. lateral-shuffle-right
# Difference in line 1232: curve-left-spin-Rfirst vs. lateral-shuffle-left
# Difference in line 1233: curve-left-spin-Rfirst vs. jump-two-leg
# Difference in line 1234: v-cut-left-Rfirst vs. curve-left-spin-Rfirst
# Difference in line 1235: curve-left-spin-Lfirst vs. curve-right-spin-Lfirst
# Difference in line 1236: v-cut-left-Lfirst vs. jump-one-leg
# Difference in line 1237: curve-left-spin-Lfirst vs. curve-right-spin-Lfirst
# Difference in line 1239: walk vs. curve-right-step
# Difference in line 1240: curve-left-spin-Lfirst vs. curve-right-spin-Lfirst
# Difference in line 1242: stair-down vs. stair-up
# Difference in line 1245: v-cut-left-Rfirst vs. jump-two-leg
# Difference in line 1246: v-cut-left-Rfirst vs. jump-two-leg
# Difference in line 1250: v-cut-left-Rfirst vs. jump-two-leg
# Difference in line 1251: walk vs. curve-left-step
# Difference in line 1252: curve-left-step vs. curve-right-step
# Difference in line 1255: stair-down vs. lateral-shuffle-right
# Difference in line 1264: curve-left-step vs. curve-right-step
# Difference in line 1265: v-cut-left-Rfirst vs. curve-left-spin-Rfirst
# Difference in line 1270: v-cut-right-Rfirst vs. v-cut-right-Lfirst
# Difference in line 1272: stair-down vs. lateral-shuffle-left
# Difference in line 1274: walk vs. curve-right-step
# Difference in line 1277: stair-down vs. lateral-shuffle-right
# Difference in line 1281: stair-down vs. lateral-shuffle-left
# Difference in line 1284: stair-down vs. lateral-shuffle-right
# Difference in line 1292: walk vs. stair-up
# Difference in line 1293: v-cut-left-Rfirst vs. jump-two-leg
# Difference in line 1304: curve-right-step vs. curve-left-step
# Difference in line 1306: jump-two-leg vs. jump-one-leg
# Difference in line 1309: curve-left-step vs. walk
# Difference in line 1314: v-cut-right-Lfirst vs. jump-one-leg
# Difference in line 1315: jump-one-leg vs. lateral-shuffle-right
# Difference in line 1316: curve-right-step vs. walk
# Difference in line 1321: v-cut-right-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 1324: curve-left-step vs. walk
# Difference in line 1335: curve-left-step vs. walk
# Difference in line 1336: v-cut-left-Rfirst vs. curve-left-spin-Rfirst
# Difference in line 1338: jump-two-leg vs. jump-one-leg
# Difference in line 1342: curve-right-step vs. walk
# Difference in line 1352: v-cut-left-Rfirst vs. curve-left-spin-Rfirst
# Difference in line 1362: curve-right-step vs. walk
# Difference in line 1371: curve-right-step vs. walk
# Difference in line 1377: jump-two-leg vs. jump-one-leg
# Difference in line 1382: curve-right-step vs. walk
# Difference in line 1394: curve-right-step vs. walk
# Difference in line 1398: v-cut-right-Lfirst vs. v-cut-right-Rfirst
# Difference in line 1399: lateral-shuffle-right vs. lateral-shuffle-left
# Difference in line 1408: v-cut-left-Rfirst vs. curve-left-spin-Rfirst
# Difference in line 1420: jump-two-leg vs. jump-one-leg
# Difference in line 1429: curve-right-step vs. walk
# Difference in line 1439: curve-right-step vs. curve-left-step
# Difference in line 1445: jump-two-leg vs. v-cut-left-Lfirst
# Difference in line 1449: v-cut-right-Rfirst vs. curve-left-spin-Rfirst
# Difference in line 1452: curve-left-step vs. walk
# Difference in line 1461: curve-right-step vs. walk
# Difference in line 1467: sit vs. stand
# Difference in line 1481: curve-left-step vs. walk
# Difference in line 1491: curve-right-step vs. curve-left-step
# Difference in line 1492: curve-right-step vs. walk
# Difference in line 1505: run vs. lateral-shuffle-left
# Difference in line 1506: jump-two-leg vs. jump-one-leg
# Difference in line 1509: lateral-shuffle-right vs. lateral-shuffle-left
# Difference in line 1514: curve-right-step vs. walk
# Difference in line 1522: curve-right-step vs. walk
# Difference in line 1523: jump-two-leg vs. jump-one-leg
# Difference in line 1524: curve-right-step vs. walk
# Difference in line 1526: v-cut-left-Lfirst vs. jump-one-leg
# Difference in line 1527: curve-right-step vs. walk
# Difference in line 1530: walk vs. curve-left-step
# Difference in line 1532: curve-right-step vs. walk
# Difference in line 1533: stand vs. sit
# Difference in line 1537: v-cut-right-Lfirst vs. jump-one-leg
# Difference in line 1544: v-cut-left-Rfirst vs. curve-left-spin-Rfirst
# Difference in line 1555: v-cut-right-Lfirst vs. jump-one-leg
# Difference in line 1562: sit vs. stand
# Difference in line 1566: curve-left-step vs. walk
# Difference in line 1568: lateral-shuffle-right vs. lateral-shuffle-left
# Difference in line 1575: sit vs. stand
# Difference in line 1579: jump-two-leg vs. jump-one-leg
# Difference in line 1585: stand vs. sit
# Difference in line 1609: curve-right-step vs. walk
# Difference in line 1611: lateral-shuffle-right vs. lateral-shuffle-left
# Difference in line 1627: curve-left-step vs. walk
# Difference in line 1633: jump-two-leg vs. lateral-shuffle-right
# Difference in line 1636: sit vs. stand
# Difference in line 1639: curve-right-step vs. walk
# Difference in line 1663: curve-left-step vs. walk
# Difference in line 1671: v-cut-left-Rfirst vs. lateral-shuffle-left
# Difference in line 1684: jump-one-leg vs. jump-two-leg
# Difference in line 1688: run vs. lateral-shuffle-left
# Difference in line 1689: stair-up vs. stair-down
# Difference in line 1698: v-cut-right-Rfirst vs. v-cut-right-Lfirst
# Difference in line 1705: v-cut-left-Rfirst vs. curve-left-spin-Rfirst
# Difference in line 1706: sit vs. stand
# Difference in line 1709: curve-left-step vs. walk
# Difference in line 1710: curve-left-spin-Rfirst vs. curve-left-spin-Lfirst
# Difference in line 1714: curve-left-step vs. walk
# Difference in line 1717: v-cut-left-Rfirst vs. curve-left-spin-Rfirst
# 605 differences found in total.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

classes = ['run', 'walk', 'stand', 'sit', 'sit-to-stand', 'stand-to-sit', 
        'stair-up', 'stair-down', 'jump-one-leg', 'jump-two-leg', 'curve-left-step', 
        'curve-right-step', 'curve-left-spin-Lfirst', 'curve-left-spin-Rfirst', 
        'curve-right-spin-Lfirst', 'curve-right-spin-Rfirst', 'lateral-shuffle-left', 
        'lateral-shuffle-right','v-cut-left-Lfirst', 'v-cut-left-Rfirst', 'v-cut-right-Lfirst', 'v-cut-right-Rfirst']

# %%
def compare_results(file1, file2):
    df1 = pd.read_csv(file1).values[:,2]
    df2 = pd.read_csv(file2).values[:,2]
    
    d1 = dict.fromkeys(classes, 0)
    d2 = dict.fromkeys(classes, 0)
    
    count = 0
    for idx, (i,j) in enumerate(zip(df1,df2)):
        
        d1[i] += 1
        d2[j] += 1
        
        if i != j:
            print("Difference in line {}: {} vs. {}".format(idx, i,j))
            count += 1
    
    print("{} differences found in total.".format(count))
    
    def plot_hist(d1):
        objects = np.arange(0,22)
        y_pos = np.arange(len(objects))
        performance = d1.values()

        plt.bar(y_pos, performance, align='center', alpha=0.5)
        plt.xticks(y_pos, objects)
        plt.ylabel('occurences')
        plt.title('distribution over labels for d1')

        plt.show()
        
    plot_hist(d1)
    plot_hist(d2)

# %%
compare_results("../old submissions/abgabe1.csv","../abgabe_Lazarus_weird.csv")
# Out:
# Difference in line 0: walk vs. curve-left-step
# Difference in line 6: stair-down vs. lateral-shuffle-right
# Difference in line 13: run vs. lateral-shuffle-right
# Difference in line 18: v-cut-left-Rfirst vs. v-cut-right-Rfirst
# Difference in line 19: curve-left-spin-Lfirst vs. curve-right-spin-Lfirst
# Difference in line 27: curve-left-step vs. curve-right-step
# Difference in line 30: v-cut-left-Rfirst vs. curve-left-spin-Rfirst
# Difference in line 32: v-cut-right-Rfirst vs. v-cut-left-Lfirst
# Difference in line 34: curve-left-step vs. lateral-shuffle-right
# Difference in line 35: v-cut-left-Rfirst vs. curve-left-spin-Rfirst
# Difference in line 38: curve-right-step vs. walk
# Difference in line 40: walk vs. curve-right-step
# Difference in line 41: curve-left-step vs. curve-right-step
# Difference in line 42: jump-one-leg vs. lateral-shuffle-left
# Difference in line 43: jump-two-leg vs. run
# Difference in line 47: curve-left-step vs. curve-right-step
# Difference in line 53: curve-left-step vs. curve-right-step
# Difference in line 54: v-cut-left-Lfirst vs. v-cut-right-Lfirst
# Difference in line 57: curve-left-step vs. curve-right-step
# Difference in line 60: v-cut-left-Rfirst vs. curve-left-spin-Rfirst
# Difference in line 61: v-cut-left-Rfirst vs. curve-left-spin-Rfirst
# Difference in line 63: jump-two-leg vs. run
# Difference in line 64: curve-left-spin-Rfirst vs. curve-left-spin-Lfirst
# Difference in line 67: curve-left-spin-Rfirst vs. curve-left-spin-Lfirst
# Difference in line 70: walk vs. curve-right-step
# Difference in line 71: curve-left-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 73: walk vs. curve-right-step
# Difference in line 74: walk vs. curve-right-step
# Difference in line 75: jump-two-leg vs. run
# Difference in line 77: curve-left-step vs. curve-right-step
# Difference in line 79: v-cut-right-Rfirst vs. v-cut-right-Lfirst
# Difference in line 81: walk vs. curve-right-step
# Difference in line 84: v-cut-right-Rfirst vs. v-cut-right-Lfirst
# Difference in line 86: curve-left-step vs. curve-right-step
# Difference in line 92: v-cut-left-Lfirst vs. v-cut-right-Lfirst
# Difference in line 97: v-cut-right-Rfirst vs. v-cut-right-Lfirst
# Difference in line 98: walk vs. curve-right-step
# Difference in line 99: stair-down vs. curve-right-spin-Lfirst
# Difference in line 105: curve-left-spin-Rfirst vs. curve-left-spin-Lfirst
# Difference in line 106: stair-down vs. curve-right-step
# Difference in line 107: curve-left-step vs. curve-right-step
# Difference in line 112: curve-left-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 118: walk vs. curve-right-step
# Difference in line 122: curve-left-step vs. curve-right-step
# Difference in line 124: jump-two-leg vs. run
# Difference in line 127: v-cut-right-Lfirst vs. curve-right-spin-Lfirst
# Difference in line 129: curve-left-step vs. curve-right-step
# Difference in line 133: curve-left-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 137: v-cut-left-Rfirst vs. v-cut-right-Rfirst
# Difference in line 138: v-cut-right-Rfirst vs. v-cut-left-Lfirst
# Difference in line 139: lateral-shuffle-left vs. stair-down
# Difference in line 141: jump-two-leg vs. v-cut-left-Lfirst
# Difference in line 142: curve-left-spin-Rfirst vs. v-cut-left-Rfirst
# Difference in line 145: v-cut-right-Lfirst vs. jump-one-leg
# Difference in line 147: curve-left-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 156: v-cut-right-Lfirst vs. v-cut-left-Lfirst
# Difference in line 158: jump-one-leg vs. stair-down
# Difference in line 163: curve-left-step vs. curve-right-step
# Difference in line 166: jump-one-leg vs. lateral-shuffle-left
# Difference in line 168: curve-right-step vs. curve-left-step
# Difference in line 169: stair-down vs. lateral-shuffle-right
# Difference in line 173: walk vs. stair-up
# Difference in line 174: jump-two-leg vs. run
# Difference in line 175: v-cut-right-Rfirst vs. v-cut-left-Rfirst
# Difference in line 176: v-cut-right-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 178: curve-right-step vs. curve-left-step
# Difference in line 179: v-cut-right-Rfirst vs. v-cut-right-Lfirst
# Difference in line 181: curve-left-step vs. curve-right-step
# Difference in line 183: curve-left-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 184: stair-up vs. stair-down
# Difference in line 187: jump-one-leg vs. stair-down
# Difference in line 193: curve-right-spin-Lfirst vs. v-cut-right-Lfirst
# Difference in line 198: v-cut-right-Rfirst vs. v-cut-left-Lfirst
# Difference in line 201: v-cut-left-Rfirst vs. curve-left-spin-Rfirst
# Difference in line 204: v-cut-right-Rfirst vs. v-cut-left-Lfirst
# Difference in line 205: curve-left-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 206: jump-two-leg vs. curve-left-spin-Rfirst
# Difference in line 209: curve-left-spin-Lfirst vs. curve-left-spin-Rfirst
# Difference in line 215: v-cut-right-Lfirst vs. v-cut-right-Rfirst
# Difference in line 218: curve-left-step vs. curve-right-step
# Difference in line 221: v-cut-right-Rfirst vs. v-cut-right-Lfirst
# Difference in line 222: run vs. lateral-shuffle-right
# Difference in line 228: curve-left-spin-Rfirst vs. curve-left-spin-Lfirst
# Difference in line 232: run vs. lateral-shuffle-right
# Difference in line 233: walk vs. curve-right-step
# Difference in line 234: curve-left-step vs. curve-right-step
# Difference in line 239: curve-left-step vs. curve-right-step
# Difference in line 241: stair-down vs. lateral-shuffle-left
# Difference in line 242: v-cut-left-Rfirst vs. v-cut-right-Rfirst
# Difference in line 244: curve-left-step vs. curve-right-step
# Difference in line 245: curve-left-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 253: curve-left-step vs. curve-right-step
# Difference in line 255: stand vs. sit
# Difference in line 256: v-cut-right-Rfirst vs. v-cut-left-Lfirst
# Difference in line 257: jump-two-leg vs. stair-up
# Difference in line 260: curve-left-step vs. curve-right-step
# Difference in line 261: curve-left-step vs. curve-right-step
# Difference in line 268: curve-left-spin-Rfirst vs. curve-left-spin-Lfirst
# Difference in line 280: stand vs. sit
# Difference in line 281: jump-one-leg vs. stair-down
# Difference in line 284: jump-two-leg vs. v-cut-left-Rfirst
# Difference in line 287: curve-left-spin-Rfirst vs. curve-left-spin-Lfirst
# Difference in line 300: run vs. lateral-shuffle-right
# Difference in line 303: jump-one-leg vs. run
# Difference in line 306: stair-down vs. lateral-shuffle-left
# Difference in line 313: jump-two-leg vs. v-cut-left-Lfirst
# Difference in line 314: walk vs. curve-right-step
# Difference in line 316: v-cut-left-Rfirst vs. v-cut-right-Rfirst
# Difference in line 329: curve-left-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 330: v-cut-left-Rfirst vs. v-cut-right-Rfirst
# Difference in line 332: stand vs. sit
# Difference in line 333: jump-one-leg vs. stair-down
# Difference in line 337: v-cut-left-Rfirst vs. v-cut-right-Rfirst
# Difference in line 339: run vs. lateral-shuffle-right
# Difference in line 349: stair-down vs. lateral-shuffle-right
# Difference in line 351: stand vs. sit
# Difference in line 352: curve-left-step vs. curve-right-step
# Difference in line 358: curve-left-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 363: curve-left-step vs. curve-right-step
# Difference in line 364: curve-left-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 367: stand vs. sit
# Difference in line 370: curve-left-step vs. curve-right-step
# Difference in line 371: v-cut-left-Lfirst vs. v-cut-right-Rfirst
# Difference in line 374: curve-left-spin-Rfirst vs. curve-left-step
# Difference in line 380: jump-two-leg vs. run
# Difference in line 388: v-cut-left-Rfirst vs. curve-left-spin-Rfirst
# Difference in line 392: v-cut-right-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 394: curve-left-spin-Rfirst vs. curve-left-spin-Lfirst
# Difference in line 397: jump-one-leg vs. run
# Difference in line 400: jump-one-leg vs. curve-left-step
# Difference in line 401: curve-left-step vs. curve-right-step
# Difference in line 404: jump-two-leg vs. v-cut-left-Lfirst
# Difference in line 410: curve-left-spin-Rfirst vs. curve-left-spin-Lfirst
# Difference in line 418: jump-one-leg vs. stair-down
# Difference in line 424: walk vs. curve-right-step
# Difference in line 427: v-cut-right-Rfirst vs. v-cut-right-Lfirst
# Difference in line 430: walk vs. curve-right-step
# Difference in line 431: jump-one-leg vs. lateral-shuffle-left
# Difference in line 432: stand vs. sit
# Difference in line 433: curve-left-spin-Rfirst vs. stair-down
# Difference in line 439: walk vs. curve-right-step
# Difference in line 441: lateral-shuffle-left vs. lateral-shuffle-right
# Difference in line 442: curve-left-step vs. stair-down
# Difference in line 443: run vs. curve-left-step
# Difference in line 445: jump-one-leg vs. v-cut-right-Lfirst
# Difference in line 450: jump-one-leg vs. v-cut-right-Lfirst
# Difference in line 451: run vs. walk
# Difference in line 458: jump-one-leg vs. jump-two-leg
# Difference in line 462: jump-one-leg vs. v-cut-right-Lfirst
# Difference in line 463: walk vs. curve-left-step
# Difference in line 465: v-cut-right-Lfirst vs. curve-right-step
# Difference in line 466: stair-down vs. curve-left-step
# Difference in line 467: curve-left-step vs. curve-right-step
# Difference in line 471: v-cut-left-Rfirst vs. curve-left-spin-Lfirst
# Difference in line 477: run vs. lateral-shuffle-left
# Difference in line 481: curve-left-step vs. curve-right-step
# Difference in line 483: lateral-shuffle-left vs. lateral-shuffle-right
# Difference in line 484: run vs. lateral-shuffle-left
# Difference in line 487: v-cut-right-Lfirst vs. v-cut-right-Rfirst
# Difference in line 488: run vs. lateral-shuffle-left
# Difference in line 497: run vs. walk
# Difference in line 500: jump-one-leg vs. v-cut-right-Lfirst
# Difference in line 502: v-cut-left-Rfirst vs. curve-left-step
# Difference in line 508: run vs. lateral-shuffle-left
# Difference in line 509: jump-one-leg vs. v-cut-right-Rfirst
# Difference in line 511: lateral-shuffle-left vs. lateral-shuffle-right
# Difference in line 512: stair-down vs. walk
# Difference in line 515: run vs. lateral-shuffle-right
# Difference in line 520: v-cut-left-Lfirst vs. curve-left-spin-Rfirst
# Difference in line 524: curve-left-step vs. v-cut-right-Rfirst
# Difference in line 530: jump-two-leg vs. stair-up
# Difference in line 532: jump-one-leg vs. jump-two-leg
# Difference in line 539: stand vs. sit
# Difference in line 543: stair-up vs. stair-down
# Difference in line 552: curve-right-step vs. curve-left-spin-Lfirst
# Difference in line 555: jump-one-leg vs. jump-two-leg
# Difference in line 558: stair-down vs. curve-right-step
# Difference in line 561: stair-up vs. stair-down
# Difference in line 564: curve-left-spin-Rfirst vs. v-cut-left-Rfirst
# Difference in line 567: jump-one-leg vs. v-cut-right-Lfirst
# Difference in line 572: stair-up vs. stair-down
# Difference in line 575: v-cut-right-Lfirst vs. jump-two-leg
# Difference in line 577: v-cut-right-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 578: jump-one-leg vs. curve-right-spin-Lfirst
# Difference in line 579: jump-one-leg vs. jump-two-leg
# Difference in line 588: v-cut-right-Lfirst vs. curve-right-step
# Difference in line 590: stair-up vs. stair-down
# Difference in line 592: stair-down vs. curve-right-step
# Difference in line 593: jump-one-leg vs. v-cut-right-Rfirst
# Difference in line 594: jump-one-leg vs. stair-up
# Difference in line 597: stand vs. sit
# Difference in line 601: curve-right-step vs. curve-left-spin-Rfirst
# Difference in line 609: curve-left-spin-Rfirst vs. curve-left-spin-Lfirst
# Difference in line 611: walk vs. curve-right-step
# Difference in line 612: jump-one-leg vs. curve-left-spin-Lfirst
# Difference in line 613: jump-one-leg vs. jump-two-leg
# Difference in line 614: lateral-shuffle-right vs. lateral-shuffle-left
# Difference in line 615: v-cut-left-Rfirst vs. curve-left-step
# Difference in line 616: v-cut-right-Rfirst vs. curve-right-step
# Difference in line 627: walk vs. curve-left-step
# Difference in line 633: curve-left-spin-Rfirst vs. v-cut-left-Rfirst
# Difference in line 636: curve-left-step vs. curve-right-step
# Difference in line 640: run vs. curve-left-step
# Difference in line 641: stand vs. sit
# Difference in line 645: curve-right-step vs. jump-one-leg
# Difference in line 647: v-cut-left-Rfirst vs. curve-left-spin-Rfirst
# Difference in line 649: jump-one-leg vs. v-cut-right-Lfirst
# Difference in line 650: jump-one-leg vs. curve-right-spin-Lfirst
# Difference in line 652: lateral-shuffle-left vs. run
# Difference in line 653: curve-left-step vs. run
# Difference in line 654: v-cut-right-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 657: curve-left-spin-Rfirst vs. v-cut-left-Lfirst
# Difference in line 662: walk vs. curve-left-step
# Difference in line 667: v-cut-right-Rfirst vs. curve-right-spin-Rfirst
# Difference in line 668: jump-one-leg vs. curve-right-spin-Lfirst
# Difference in line 671: jump-one-leg vs. jump-two-leg
# Difference in line 673: walk vs. curve-right-step
# Difference in line 674: jump-one-leg vs. stair-up
# Difference in line 675: run vs. curve-left-step
# Difference in line 677: lateral-shuffle-right vs. lateral-shuffle-left
# Difference in line 679: run vs. lateral-shuffle-left
# Difference in line 684: curve-left-step vs. curve-left-spin-Lfirst
# Difference in line 685: jump-one-leg vs. stair-up
# Difference in line 687: curve-left-spin-Rfirst vs. curve-left-step
# Difference in line 690: jump-one-leg vs. curve-left-spin-Lfirst
# Difference in line 691: lateral-shuffle-left vs. lateral-shuffle-right
# Difference in line 694: stair-down vs. v-cut-right-Rfirst
# Difference in line 696: v-cut-right-Rfirst vs. curve-right-step
# Difference in line 697: curve-left-spin-Rfirst vs. curve-left-spin-Lfirst
# Difference in line 710: curve-left-step vs. walk
# Difference in line 712: curve-left-spin-Rfirst vs. curve-left-step
# Difference in line 718: run vs. lateral-shuffle-left
# Difference in line 721: curve-left-spin-Lfirst vs. curve-right-spin-Lfirst
# Difference in line 722: stair-down vs. curve-left-step
# Difference in line 727: stand vs. sit
# Difference in line 732: run vs. lateral-shuffle-left
# Difference in line 734: walk vs. curve-left-step
# Difference in line 735: curve-left-step vs. curve-right-step
# Difference in line 737: stair-down vs. lateral-shuffle-right
# Difference in line 738: v-cut-left-Rfirst vs. curve-left-step
# Difference in line 739: stair-up vs. lateral-shuffle-right
# Difference in line 742: jump-one-leg vs. v-cut-right-Rfirst
# Difference in line 743: stand vs. sit
# Difference in line 746: v-cut-right-Rfirst vs. curve-right-step
# Difference in line 748: walk vs. curve-right-step
# Difference in line 751: stair-up vs. lateral-shuffle-right
# Difference in line 754: v-cut-left-Lfirst vs. v-cut-right-Rfirst
# Difference in line 755: stair-up vs. v-cut-right-Rfirst
# Difference in line 756: curve-left-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 758: jump-one-leg vs. curve-right-step
# Difference in line 762: stair-up vs. jump-one-leg
# Difference in line 765: jump-one-leg vs. curve-left-spin-Lfirst
# Difference in line 766: curve-left-step vs. curve-right-step
# Difference in line 770: walk vs. curve-left-step
# Difference in line 771: v-cut-left-Lfirst vs. v-cut-right-Rfirst
# Difference in line 772: v-cut-right-Lfirst vs. curve-right-step
# Difference in line 773: jump-one-leg vs. jump-two-leg
# Difference in line 776: stair-up vs. stair-down
# Difference in line 777: v-cut-left-Rfirst vs. lateral-shuffle-left
# Difference in line 782: curve-left-step vs. curve-right-step
# Difference in line 790: jump-one-leg vs. v-cut-left-Lfirst
# Difference in line 791: curve-left-spin-Rfirst vs. curve-left-spin-Lfirst
# Difference in line 792: curve-left-spin-Rfirst vs. curve-left-spin-Lfirst
# Difference in line 795: lateral-shuffle-left vs. curve-left-spin-Lfirst
# Difference in line 797: lateral-shuffle-left vs. curve-right-step
# Difference in line 798: v-cut-right-Lfirst vs. curve-right-step
# Difference in line 801: v-cut-right-Lfirst vs. curve-right-spin-Rfirst
# Difference in line 803: jump-one-leg vs. curve-left-spin-Lfirst
# Difference in line 804: stand vs. sit
# Difference in line 807: curve-left-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 809: v-cut-right-Rfirst vs. curve-right-step
# Difference in line 811: walk vs. curve-left-step
# Difference in line 820: stand vs. sit
# Difference in line 828: curve-right-step vs. walk
# Difference in line 836: jump-one-leg vs. curve-right-spin-Lfirst
# Difference in line 837: v-cut-left-Lfirst vs. v-cut-right-Rfirst
# Difference in line 839: jump-one-leg vs. jump-two-leg
# Difference in line 843: v-cut-right-Lfirst vs. curve-right-step
# Difference in line 850: stand vs. sit
# Difference in line 853: jump-one-leg vs. v-cut-right-Lfirst
# Difference in line 855: stair-up vs. stair-down
# Difference in line 856: curve-left-spin-Rfirst vs. curve-left-step
# Difference in line 857: curve-left-step vs. curve-right-step
# Difference in line 859: lateral-shuffle-left vs. run
# Difference in line 862: jump-one-leg vs. jump-two-leg
# Difference in line 863: jump-one-leg vs. jump-two-leg
# Difference in line 865: v-cut-left-Rfirst vs. curve-left-spin-Rfirst
# Difference in line 870: jump-one-leg vs. v-cut-right-Lfirst
# Difference in line 879: v-cut-right-Rfirst vs. v-cut-right-Lfirst
# Difference in line 889: lateral-shuffle-left vs. curve-left-spin-Rfirst
# Difference in line 893: stand vs. sit
# Difference in line 896: sit-to-stand vs. curve-left-spin-Rfirst
# Difference in line 897: jump-one-leg vs. jump-two-leg
# Difference in line 899: stand vs. sit
# Difference in line 906: v-cut-right-Lfirst vs. curve-right-spin-Rfirst
# Difference in line 907: jump-one-leg vs. jump-two-leg
# Difference in line 912: stand vs. sit
# Difference in line 915: stair-down vs. v-cut-left-Rfirst
# Difference in line 916: stair-down vs. lateral-shuffle-right
# Difference in line 917: stair-down vs. lateral-shuffle-right
# Difference in line 919: stair-down vs. v-cut-right-Lfirst
# Difference in line 926: curve-right-spin-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 933: walk vs. curve-left-step
# Difference in line 934: lateral-shuffle-left vs. lateral-shuffle-right
# Difference in line 936: stair-down vs. lateral-shuffle-left
# Difference in line 938: walk vs. curve-right-step
# Difference in line 946: jump-one-leg vs. jump-two-leg
# Difference in line 948: walk vs. curve-right-step
# Difference in line 951: stair-down vs. lateral-shuffle-left
# Difference in line 963: stair-down vs. lateral-shuffle-right
# Difference in line 967: curve-right-spin-Lfirst vs. v-cut-right-Lfirst
# Difference in line 970: stand vs. sit
# Difference in line 971: run vs. stair-down
# Difference in line 972: stair-down vs. curve-left-step
# Difference in line 975: stand vs. sit
# Difference in line 976: walk vs. curve-right-step
# Difference in line 978: v-cut-right-Rfirst vs. v-cut-right-Lfirst
# Difference in line 982: jump-one-leg vs. jump-two-leg
# Difference in line 989: stair-down vs. v-cut-right-Rfirst
# Difference in line 993: jump-one-leg vs. jump-two-leg
# Difference in line 995: stair-down vs. curve-right-step
# Difference in line 996: curve-left-spin-Lfirst vs. curve-right-spin-Lfirst
# Difference in line 1004: lateral-shuffle-left vs. curve-right-step
# Difference in line 1006: jump-one-leg vs. v-cut-right-Lfirst
# Difference in line 1009: curve-right-spin-Lfirst vs. v-cut-right-Lfirst
# Difference in line 1011: stand vs. sit
# Difference in line 1024: stand vs. sit
# Difference in line 1026: jump-one-leg vs. jump-two-leg
# Difference in line 1039: stair-down vs. v-cut-right-Lfirst
# Difference in line 1040: v-cut-right-Rfirst vs. v-cut-right-Lfirst
# Difference in line 1045: stand vs. sit
# Difference in line 1046: walk vs. curve-left-step
# Difference in line 1049: walk vs. curve-left-step
# Difference in line 1050: jump-one-leg vs. v-cut-right-Lfirst
# Difference in line 1059: walk vs. curve-right-step
# Difference in line 1066: v-cut-right-Rfirst vs. v-cut-right-Lfirst
# Difference in line 1069: v-cut-right-Rfirst vs. lateral-shuffle-right
# Difference in line 1071: jump-one-leg vs. jump-two-leg
# Difference in line 1074: stair-down vs. v-cut-right-Rfirst
# Difference in line 1076: lateral-shuffle-right vs. curve-right-step
# Difference in line 1084: lateral-shuffle-left vs. v-cut-right-Lfirst
# Difference in line 1087: curve-left-step vs. walk
# Difference in line 1097: curve-left-spin-Rfirst vs. curve-left-spin-Lfirst
# Difference in line 1108: stair-down vs. lateral-shuffle-right
# Difference in line 1109: v-cut-left-Rfirst vs. curve-left-spin-Rfirst
# Difference in line 1110: walk vs. curve-left-step
# Difference in line 1116: lateral-shuffle-left vs. v-cut-right-Lfirst
# Difference in line 1129: v-cut-left-Rfirst vs. curve-left-spin-Rfirst
# Difference in line 1134: jump-one-leg vs. v-cut-right-Lfirst
# Difference in line 1144: v-cut-left-Lfirst vs. jump-two-leg
# Difference in line 1145: walk vs. curve-left-step
# Difference in line 1146: stair-down vs. v-cut-right-Lfirst
# Difference in line 1149: stair-down vs. v-cut-right-Lfirst
# Difference in line 1152: lateral-shuffle-left vs. jump-one-leg
# Difference in line 1154: stair-down vs. lateral-shuffle-right
# Difference in line 1155: lateral-shuffle-right vs. curve-right-step
# Difference in line 1158: jump-two-leg vs. v-cut-right-Rfirst
# Difference in line 1162: stair-down vs. v-cut-right-Lfirst
# Difference in line 1163: stand vs. sit
# Difference in line 1167: v-cut-right-Rfirst vs. v-cut-right-Lfirst
# Difference in line 1172: stand vs. sit
# Difference in line 1181: stair-down vs. v-cut-right-Lfirst
# Difference in line 1184: walk vs. curve-right-step
# Difference in line 1190: v-cut-right-Rfirst vs. v-cut-right-Lfirst
# Difference in line 1192: stair-down vs. jump-one-leg
# Difference in line 1193: stair-up vs. run
# Difference in line 1196: walk vs. curve-right-step
# Difference in line 1197: lateral-shuffle-left vs. v-cut-right-Lfirst
# Difference in line 1217: stair-down vs. lateral-shuffle-right
# Difference in line 1224: v-cut-right-Rfirst vs. v-cut-right-Lfirst
# Difference in line 1226: stair-down vs. stair-up
# Difference in line 1230: stand vs. sit
# Difference in line 1231: stair-up vs. lateral-shuffle-right
# Difference in line 1232: curve-left-spin-Rfirst vs. v-cut-right-Lfirst
# Difference in line 1233: curve-left-spin-Rfirst vs. v-cut-left-Rfirst
# Difference in line 1234: v-cut-left-Rfirst vs. curve-left-spin-Rfirst
# Difference in line 1237: curve-left-spin-Lfirst vs. curve-right-spin-Lfirst
# Difference in line 1239: walk vs. curve-right-step
# Difference in line 1241: curve-left-step vs. walk
# Difference in line 1242: stair-down vs. stair-up
# Difference in line 1248: v-cut-right-Rfirst vs. v-cut-right-Lfirst
# Difference in line 1251: walk vs. curve-right-step
# Difference in line 1254: jump-one-leg vs. jump-two-leg
# Difference in line 1255: stair-down vs. lateral-shuffle-right
# Difference in line 1265: v-cut-left-Rfirst vs. curve-left-spin-Rfirst
# Difference in line 1270: v-cut-right-Rfirst vs. v-cut-right-Lfirst
# Difference in line 1272: stair-down vs. curve-right-step
# Difference in line 1274: walk vs. curve-right-step
# Difference in line 1277: stair-down vs. lateral-shuffle-right
# Difference in line 1281: stair-down vs. v-cut-right-Lfirst
# Difference in line 1284: stair-down vs. v-cut-left-Rfirst
# Difference in line 1292: walk vs. curve-left-step
# Difference in line 1296: stand vs. sit
# Difference in line 1300: v-cut-right-Rfirst vs. curve-right-spin-Rfirst
# Difference in line 1306: jump-two-leg vs. v-cut-left-Lfirst
# Difference in line 1309: curve-left-step vs. walk
# Difference in line 1314: v-cut-right-Lfirst vs. jump-one-leg
# Difference in line 1315: jump-one-leg vs. v-cut-right-Lfirst
# Difference in line 1316: curve-right-step vs. walk
# Difference in line 1320: walk vs. curve-right-step
# Difference in line 1321: v-cut-right-Rfirst vs. curve-right-spin-Lfirst
# Difference in line 1328: walk vs. curve-right-step
# Difference in line 1331: curve-left-step vs. walk
# Difference in line 1335: curve-left-step vs. walk
# Difference in line 1336: v-cut-left-Rfirst vs. curve-left-spin-Rfirst
# Difference in line 1352: v-cut-left-Rfirst vs. curve-left-spin-Rfirst
# Difference in line 1353: jump-one-leg vs. v-cut-right-Lfirst
# Difference in line 1366: stand vs. sit
# Difference in line 1370: jump-one-leg vs. v-cut-right-Lfirst
# Difference in line 1374: v-cut-right-Rfirst vs. curve-right-spin-Rfirst
# Difference in line 1377: jump-two-leg vs. v-cut-right-Lfirst
# Difference in line 1386: v-cut-right-Rfirst vs. curve-right-spin-Rfirst
# Difference in line 1392: stand vs. sit
# Difference in line 1398: v-cut-right-Lfirst vs. curve-right-spin-Rfirst
# Difference in line 1399: lateral-shuffle-right vs. lateral-shuffle-left
# Difference in line 1407: walk vs. curve-right-step
# Difference in line 1408: v-cut-left-Rfirst vs. curve-left-spin-Rfirst
# Difference in line 1409: stand vs. sit
# Difference in line 1420: jump-two-leg vs. v-cut-right-Lfirst
# Difference in line 1426: walk vs. curve-left-step
# Difference in line 1445: jump-two-leg vs. v-cut-left-Rfirst
# Difference in line 1451: jump-two-leg vs. v-cut-left-Lfirst
# Difference in line 1454: walk vs. curve-left-step
# Difference in line 1459: walk vs. curve-right-step
# Difference in line 1488: lateral-shuffle-right vs. v-cut-right-Rfirst
# Difference in line 1490: stand vs. sit
# Difference in line 1505: run vs. lateral-shuffle-left
# Difference in line 1506: jump-two-leg vs. v-cut-right-Lfirst
# Difference in line 1509: lateral-shuffle-right vs. lateral-shuffle-left
# Difference in line 1517: jump-one-leg vs. v-cut-right-Lfirst
# Difference in line 1518: jump-one-leg vs. v-cut-right-Lfirst
# Difference in line 1523: jump-two-leg vs. v-cut-right-Lfirst
# Difference in line 1526: v-cut-left-Lfirst vs. v-cut-right-Lfirst
# Difference in line 1528: v-cut-right-Rfirst vs. curve-right-spin-Rfirst
# Difference in line 1530: walk vs. curve-left-step
# Difference in line 1533: stand vs. sit
# Difference in line 1538: lateral-shuffle-right vs. v-cut-right-Rfirst
# Difference in line 1541: jump-one-leg vs. v-cut-right-Lfirst
# Difference in line 1544: v-cut-left-Rfirst vs. curve-left-spin-Rfirst
# Difference in line 1545: v-cut-left-Lfirst vs. v-cut-right-Rfirst
# Difference in line 1546: stair-up vs. run
# Difference in line 1548: stand vs. sit
# Difference in line 1555: v-cut-right-Lfirst vs. jump-one-leg
# Difference in line 1557: v-cut-right-Rfirst vs. curve-left-spin-Lfirst
# Difference in line 1564: jump-one-leg vs. v-cut-right-Lfirst
# Difference in line 1565: stair-up vs. stair-down
# Difference in line 1566: curve-left-step vs. walk
# Difference in line 1567: jump-one-leg vs. v-cut-left-Rfirst
# Difference in line 1579: jump-two-leg vs. v-cut-right-Lfirst
# Difference in line 1585: stand vs. sit
# Difference in line 1591: walk vs. curve-right-step
# Difference in line 1595: v-cut-left-Lfirst vs. v-cut-right-Rfirst
# Difference in line 1602: jump-one-leg vs. v-cut-right-Lfirst
# Difference in line 1606: v-cut-right-Rfirst vs. v-cut-right-Lfirst
# Difference in line 1625: walk vs. curve-right-step
# Difference in line 1633: jump-two-leg vs. v-cut-right-Lfirst
# Difference in line 1651: v-cut-right-Rfirst vs. curve-right-spin-Rfirst
# Difference in line 1655: stand vs. sit
# Difference in line 1657: v-cut-right-Rfirst vs. curve-right-spin-Rfirst
# Difference in line 1660: stand vs. sit
# Difference in line 1667: stand vs. sit
# Difference in line 1678: v-cut-right-Rfirst vs. curve-right-spin-Rfirst
# Difference in line 1684: jump-one-leg vs. jump-two-leg
# Difference in line 1688: run vs. lateral-shuffle-left
# Difference in line 1694: v-cut-right-Rfirst vs. curve-right-spin-Rfirst
# Difference in line 1697: jump-one-leg vs. v-cut-right-Lfirst
# Difference in line 1698: v-cut-right-Rfirst vs. v-cut-right-Lfirst
# Difference in line 1705: v-cut-left-Rfirst vs. curve-left-spin-Rfirst
# Difference in line 1714: curve-left-step vs. walk
# Difference in line 1715: stand vs. sit
# Difference in line 1717: v-cut-left-Rfirst vs. curve-left-spin-Rfirst
# Difference in line 1726: v-cut-left-Lfirst vs. v-cut-right-Rfirst
# Difference in line 1729: walk vs. curve-right-step
# Difference in line 1733: jump-one-leg vs. run
# Difference in line 1734: jump-one-leg vs. v-cut-right-Lfirst
# Difference in line 1737: walk vs. curve-right-step
# 476 differences found in total.
